# %%
from imutils import paths
import argparse
import requests
import cv2
import os

# %%
rows = open("urls.txt").read().strip().split("\n")
total = 0

# %%
for url in rows:
    try:
        # try to download the image
        r = requests.get(url, timeout=60)

        # save the image to disk
        p = os.path.sep.join(["./tesla", "{}.jpg".format(
            str(total).zfill(8))])
        f = open(p, "wb")
        f.write(r.content)
        f.close()

        # update the counter
        print("[INFO] downloaded: {}".format(p))
        total += 1

    # handle if any exceptions are thrown during the download process
    except:
        print("[INFO] error downloading {}...skipping".format(p))
# Out:
# [INFO] downloaded: ./tesla/00000000.jpg
# [INFO] downloaded: ./tesla/00000001.jpg
# [INFO] downloaded: ./tesla/00000002.jpg
# [INFO] downloaded: ./tesla/00000003.jpg
# [INFO] downloaded: ./tesla/00000004.jpg
# [INFO] downloaded: ./tesla/00000005.jpg
# [INFO] downloaded: ./tesla/00000006.jpg
# [INFO] downloaded: ./tesla/00000007.jpg
# [INFO] downloaded: ./tesla/00000008.jpg
# [INFO] downloaded: ./tesla/00000009.jpg
# [INFO] downloaded: ./tesla/00000010.jpg
# [INFO] downloaded: ./tesla/00000011.jpg
# [INFO] downloaded: ./tesla/00000012.jpg
# [INFO] downloaded: ./tesla/00000013.jpg
# [INFO] downloaded: ./tesla/00000014.jpg
# [INFO] downloaded: ./tesla/00000015.jpg
# [INFO] downloaded: ./tesla/00000016.jpg
# [INFO] downloaded: ./tesla/00000017.jpg
# [INFO] downloaded: ./tesla/00000018.jpg
# [INFO] downloaded: ./tesla/00000019.jpg
# [INFO] downloaded: ./tesla/00000020.jpg
# [INFO] downloaded: ./tesla/00000021.jpg
# [INFO] downloaded: ./tesla/00000022.jpg
# ...

# %%
rows = open("urls2.txt").read().strip().split("\n")
total = 0

# %%
for url in rows:
    try:
        # try to download the image
        r = requests.get(url, timeout=60)

        # save the image to disk
        p = os.path.sep.join(["./shuttle", "{}.jpg".format(
            str(total).zfill(8))])
        f = open(p, "wb")
        f.write(r.content)
        f.close()

        # update the counter
        print("[INFO] downloaded: {}".format(p))
        total += 1

    # handle if any exceptions are thrown during the download process
    except:
        print("[INFO] error downloading {}...skipping".format(p))
# Out:
# [INFO] downloaded: ./shuttle/00000000.jpg
# [INFO] downloaded: ./shuttle/00000001.jpg
# [INFO] downloaded: ./shuttle/00000002.jpg
# [INFO] downloaded: ./shuttle/00000003.jpg
# [INFO] downloaded: ./shuttle/00000004.jpg
# [INFO] downloaded: ./shuttle/00000005.jpg
# [INFO] downloaded: ./shuttle/00000006.jpg
# [INFO] downloaded: ./shuttle/00000007.jpg
# [INFO] downloaded: ./shuttle/00000008.jpg
# [INFO] downloaded: ./shuttle/00000009.jpg
# [INFO] downloaded: ./shuttle/00000010.jpg
# [INFO] downloaded: ./shuttle/00000011.jpg
# [INFO] downloaded: ./shuttle/00000012.jpg
# [INFO] downloaded: ./shuttle/00000013.jpg
# [INFO] downloaded: ./shuttle/00000014.jpg
# [INFO] downloaded: ./shuttle/00000015.jpg
# [INFO] downloaded: ./shuttle/00000016.jpg
# [INFO] downloaded: ./shuttle/00000017.jpg
# [INFO] downloaded: ./shuttle/00000018.jpg
# [INFO] downloaded: ./shuttle/00000019.jpg
# [INFO] downloaded: ./shuttle/00000020.jpg
# [INFO] downloaded: ./shuttle/00000021.jpg
# ...

# %%
rows = open("urls3.txt").read().strip().split("\n")
total = 0

# %%
for url in rows:
    try:
        # try to download the image
        r = requests.get(url, timeout=60)

        # save the image to disk
        p = os.path.sep.join(["./plane", "{}.jpg".format(
            str(total).zfill(8))])
        f = open(p, "wb")
        f.write(r.content)
        f.close()

        # update the counter
        print("[INFO] downloaded: {}".format(p))
        total += 1

    # handle if any exceptions are thrown during the download process
    except:
        print("[INFO] error downloading {}...skipping".format(p))
# Out:
# [INFO] downloaded: ./plane/00000000.jpg
# [INFO] downloaded: ./plane/00000001.jpg
# [INFO] downloaded: ./plane/00000002.jpg
# [INFO] downloaded: ./plane/00000003.jpg
# [INFO] downloaded: ./plane/00000004.jpg
# [INFO] downloaded: ./plane/00000005.jpg
# [INFO] downloaded: ./plane/00000006.jpg
# [INFO] downloaded: ./plane/00000007.jpg
# [INFO] downloaded: ./plane/00000008.jpg
# [INFO] downloaded: ./plane/00000009.jpg
# [INFO] downloaded: ./plane/00000010.jpg
# [INFO] downloaded: ./plane/00000011.jpg
# [INFO] downloaded: ./plane/00000012.jpg
# [INFO] downloaded: ./plane/00000013.jpg
# [INFO] downloaded: ./plane/00000014.jpg
# [INFO] downloaded: ./plane/00000015.jpg
# [INFO] downloaded: ./plane/00000016.jpg
# [INFO] downloaded: ./plane/00000017.jpg
# [INFO] downloaded: ./plane/00000018.jpg
# [INFO] downloaded: ./plane/00000019.jpg
# [INFO] downloaded: ./plane/00000020.jpg
# [INFO] downloaded: ./plane/00000021.jpg
# [INFO] downloaded: ./plane/00000022.jpg
# ...

# %%
rows = open("jabami.txt").read().strip().split("\n")
total = 0
for url in rows:
    try:
        # try to download the image
        r = requests.get(url, timeout=60)

        # save the image to disk
        p = os.path.sep.join(["./jabami", "{}.jpg".format(
            str(total).zfill(8))])
        f = open(p, "wb")
        f.write(r.content)
        f.close()

        # update the counter
        print("[INFO] downloaded: {}".format(p))
        total += 1

    # handle if any exceptions are thrown during the download process
    except:
        print("[INFO] error downloading {}...skipping".format(p))
# Out:
# [INFO] downloaded: ./jabami/00000000.jpg
# [INFO] downloaded: ./jabami/00000001.jpg
# [INFO] downloaded: ./jabami/00000002.jpg
# [INFO] downloaded: ./jabami/00000003.jpg
# [INFO] downloaded: ./jabami/00000004.jpg
# [INFO] downloaded: ./jabami/00000005.jpg
# [INFO] downloaded: ./jabami/00000006.jpg
# [INFO] downloaded: ./jabami/00000007.jpg
# [INFO] downloaded: ./jabami/00000008.jpg
# [INFO] downloaded: ./jabami/00000009.jpg
# [INFO] downloaded: ./jabami/00000010.jpg
# [INFO] downloaded: ./jabami/00000011.jpg
# [INFO] downloaded: ./jabami/00000012.jpg
# [INFO] downloaded: ./jabami/00000013.jpg
# [INFO] downloaded: ./jabami/00000014.jpg
# [INFO] downloaded: ./jabami/00000015.jpg
# [INFO] downloaded: ./jabami/00000016.jpg
# [INFO] downloaded: ./jabami/00000017.jpg
# [INFO] downloaded: ./jabami/00000018.jpg
# [INFO] downloaded: ./jabami/00000019.jpg
# [INFO] downloaded: ./jabami/00000020.jpg
# [INFO] downloaded: ./jabami/00000021.jpg
# [INFO] downloaded: ./jabami/00000022.jpg
# ...

# %%
rows = open("edward.txt").read().strip().split("\n")
total = 0
for url in rows:
    try:
        # try to download the image
        r = requests.get(url, timeout=60)

        # save the image to disk
        p = os.path.sep.join(["./edward", "{}.jpg".format(
            str(total).zfill(8))])
        f = open(p, "wb")
        f.write(r.content)
        f.close()

        # update the counter
        print("[INFO] downloaded: {}".format(p))
        total += 1

    # handle if any exceptions are thrown during the download process
    except:
        print("[INFO] error downloading {}...skipping".format(p))
# Out:
# [INFO] downloaded: ./edward/00000000.jpg
# [INFO] downloaded: ./edward/00000001.jpg
# [INFO] downloaded: ./edward/00000002.jpg
# [INFO] downloaded: ./edward/00000003.jpg
# [INFO] downloaded: ./edward/00000004.jpg
# [INFO] downloaded: ./edward/00000005.jpg
# [INFO] downloaded: ./edward/00000006.jpg
# [INFO] downloaded: ./edward/00000007.jpg
# [INFO] downloaded: ./edward/00000008.jpg
# [INFO] downloaded: ./edward/00000009.jpg
# [INFO] downloaded: ./edward/00000010.jpg
# [INFO] downloaded: ./edward/00000011.jpg
# [INFO] downloaded: ./edward/00000012.jpg
# [INFO] downloaded: ./edward/00000013.jpg
# [INFO] downloaded: ./edward/00000014.jpg
# [INFO] downloaded: ./edward/00000015.jpg
# [INFO] downloaded: ./edward/00000016.jpg
# [INFO] downloaded: ./edward/00000017.jpg
# [INFO] downloaded: ./edward/00000018.jpg
# [INFO] downloaded: ./edward/00000019.jpg
# [INFO] downloaded: ./edward/00000020.jpg
# [INFO] downloaded: ./edward/00000021.jpg
# [INFO] downloaded: ./edward/00000022.jpg
# ...
